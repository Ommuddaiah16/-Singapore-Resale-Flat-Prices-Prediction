# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)

# %%
df_99 = pd.read_csv(r'C:\Users\igomp\OneDrive\Desktop\Projects_Data_scince\Singapore\ResaleFlatPricesBasedonApprovalDate19901999.csv')
df_12 = pd.read_csv(r'C:\Users\igomp\OneDrive\Desktop\Projects_Data_scince\Singapore\ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv')
df_14 = pd.read_csv(r'C:\Users\igomp\OneDrive\Desktop\Projects_Data_scince\Singapore\ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv')
df_16 = pd.read_csv(r'C:\Users\igomp\OneDrive\Desktop\Projects_Data_scince\Singapore\ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv')
df_17 = pd.read_csv(r'C:\Users\igomp\OneDrive\Desktop\Projects_Data_scince\Singapore\ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv')

# %%
df_99.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
df_12.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
df_14.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
df_17.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price'],
#       dtype='object')

# %%
combined_df = pd.concat([df_99, df_12, df_14, df_17], axis=0)
combined_df.head(4)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
# 2            31.0   IMPROVED                 1977        8000.0
# 3            31.0   IMPROVED                 1977        6000.0
#
#   remaining_lease
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN

# %%
combined_df.shape
# Out:
# (889780, 11)

# %%
combined_df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# dtype: object

# %% [markdown]
# # Understanding and Changing data types

# %%
combined_df.describe()
# Out:
#        floor_area_sqm  lease_commence_date  resale_price
# count   889780.000000        889780.000000  8.897800e+05
# mean        95.635975          1988.162224  3.158267e+05
# std         25.889933            10.636188  1.699335e+05
# min         28.000000          1966.000000  5.000000e+03
# 25%         73.000000          1981.000000  1.890000e+05
# 50%         93.000000          1986.000000  2.900000e+05
# 75%        113.000000          1996.000000  4.100000e+05
# max        307.000000          2022.000000  1.568888e+06

# %%
combined_df['remaining_lease'].unique()
# Out:
# array([nan, '61 years 04 months', '60 years 07 months',
#        '62 years 05 months', '62 years 01 month', '63 years',
#        '61 years 06 months', '58 years 04 months', '59 years 08 months',
#        '59 years 06 months', '60 years', '62 years 08 months', '61 years',
#        '60 years 10 months', '59 years 03 months', '61 years 05 months',
#        '60 years 04 months', '62 years', '60 years 03 months',
#        '63 years 09 months', '61 years 01 month', '61 years 10 months',
#        '58 years 06 months', '59 years 04 months', '62 years 11 months',
#        '60 years 08 months', '93 years 08 months', '93 years 07 months',
#        '60 years 01 month', '94 years 08 months', '78 years 04 months',
#        '60 years 06 months', '62 years 06 months', '58 years',
#        '70 years 08 months', '63 years 04 months', '63 years 06 months',
#        '67 years 07 months', '61 years 07 months', '68 years 02 months',
#        '68 years 03 months', '56 years', '67 years 09 months',
# ...

# %%
combined_df['storey_range'].unique()
# Out:
# array(['10 TO 12', '04 TO 06', '07 TO 09', '01 TO 03', '13 TO 15',
#        '19 TO 21', '16 TO 18', '25 TO 27', '22 TO 24', '28 TO 30',
#        '31 TO 33', '40 TO 42', '37 TO 39', '34 TO 36', '06 TO 10',
#        '01 TO 05', '11 TO 15', '16 TO 20', '21 TO 25', '26 TO 30',
#        '36 TO 40', '31 TO 35', '49 TO 51', '46 TO 48', '43 TO 45'],
#       dtype=object)

# %%
combined_df['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
combined_df['town'].unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG', 'CLEMENTI',
#        'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'QUEENSTOWN', 'SENGKANG',
#        'SERANGOON', 'TAMPINES', 'TOA PAYOH', 'WOODLANDS', 'YISHUN',
#        'LIM CHU KANG', 'SEMBAWANG', 'BUKIT PANJANG', 'PASIR RIS',
#        'PUNGGOL'], dtype=object)

# %%
combined_df['street_name'].nunique()
# Out:
# 584

# %%
combined_df['flat_model'].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'DBSS', 'Type S1',
#        'Type S2', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
combined_df['month'] = pd.to_datetime(combined_df['month'], format='%Y-%m', errors='coerce')
combined_df['lease_commence_date'] = pd.to_datetime(combined_df['lease_commence_date'], format='%Y', errors='coerce')

# %%
combined_df['block'].nunique()
# Out:
# 2710

# %%
combined_df.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date    datetime64[ns]
# resale_price                  float64
# remaining_lease                object
# dtype: object

# %% [markdown]
# # Finding and filling missing values and getting to required format

# %%
combined_df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
df_missingpercent = round((combined_df.isnull().sum()*100/len(combined_df)).sort_values(ascending=False),2)
df_missingpercent
# Out:
# remaining_lease        79.69
# month                   0.00
# town                    0.00
# flat_type               0.00
# block                   0.00
# street_name             0.00
# storey_range            0.00
# floor_area_sqm          0.00
# flat_model              0.00
# lease_commence_date     0.00
# resale_price            0.00
# dtype: float64

# %%
# Seperating months and years 
for col in ['month']:
    combined_df[f'{col}_year'] = combined_df[col].dt.year
    combined_df[f'{col}_month'] = combined_df[col].dt.month

# %%
# Seperating months and years
for col in ['lease_commence_date']:
    combined_df[f'{col}_year'] = combined_df[col].dt.year

# %%
combined_df.head()
# Out:
#        month        town flat_type block       street_name storey_range  \
# 0 1990-01-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1 1990-01-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2 1990-01-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3 1990-01-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4 1990-01-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model lease_commence_date  resale_price  \
# 0            31.0        IMPROVED          1977-01-01        9000.0
# 1            31.0        IMPROVED          1977-01-01        6000.0
# 2            31.0        IMPROVED          1977-01-01        8000.0
# 3            31.0        IMPROVED          1977-01-01        6000.0
# 4            73.0  NEW GENERATION          1976-01-01       47200.0
#
#   remaining_lease  month_year  month_month  lease_commence_date_year
# ...

# %%
combined_df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'remaining_lease', 'month_year', 'month_month',
#        'lease_commence_date_year'],
#       dtype='object')

# %% [markdown]
# # Making a copy and dropping unecessary columns

# %%
# Make a copy of the DataFrame
df_copy = combined_df.copy()

# Drop the specified columns
columns_to_drop = ['month', 'remaining_lease', 'block', 'lease_commence_date']
df_copy.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
df_copy.columns
# Out:
# Index(['town', 'flat_type', 'street_name', 'storey_range', 'floor_area_sqm',
#        'flat_model', 'resale_price', 'month_year', 'month_month',
#        'lease_commence_date_year'],
#       dtype='object')

# %%
# Considering numercal and categorical columns
categorical_columns = ['town','flat_type','storey_range','flat_model' ]
Numerical_columns = ['floor_area_sqm','month_year', 'month_month','lease_commence_date_year','resale_price']

# %%
for variable in categorical_columns:
    print(df_copy[variable].value_counts())
    print("~"*50)
# Out:
# town
# TAMPINES           77295
# YISHUN             67902
# BEDOK              64215
# JURONG WEST        63796
# WOODLANDS          62930
# ANG MO KIO         50216
# HOUGANG            48837
# BUKIT BATOK        42900
# CHOA CHU KANG      36547
# BUKIT MERAH        32998
# PASIR RIS          32039
# TOA PAYOH          30420
# SENGKANG           29841
# QUEENSTOWN         27801
# GEYLANG            27129
# CLEMENTI           27095
# BUKIT PANJANG      26291
# KALLANG/WHAMPOA    26032
# JURONG EAST        23952
# SERANGOON          21995
# BISHAN             20574
# PUNGGOL            19088
# SEMBAWANG          12845
# MARINE PARADE       7815
# CENTRAL AREA        6735
# BUKIT TIMAH         2428
# LIM CHU KANG          64
# Name: count, dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# flat_type
# 4 ROOM              337075
# 3 ROOM              285907
# 5 ROOM              186667
# EXECUTIVE            66824
# 2 ROOM               11479
# ...

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(20, 30))  # Adjust the figure size as needed
ind = 1
for variable in categorical_columns:
    plt.subplot(len(categorical_columns), 1, ind)
    sns.countplot(x=df_copy[variable], palette='Set1')
    plt.ylabel('Count')
    plt.xlabel(variable)
    plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
    ind += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# # Finding and fixing skewness and outliers

# %%
def plot(df, column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=df, x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=df, x=column, kde=True, bins=50)
    plt.title(f'Distribution Plot for {column}')

    plt.subplot(1,3,3)
    sns.violinplot(data=df, x=column)
    plt.title(f'Violin Plot for {column}')
    plt.show()

# %%
for i in Numerical_columns:
    plot(df_copy, i)

# %%
# Fixing Skewness Using Log transformation 

df_copy['resale_price_log'] = np.log(df_copy['resale_price'])

# %%
# Using IQR and clip() methods to handle the outliers and add a new column of dataframe

def outlier(df, column):
    iqr = df[column].quantile(0.75) - df[column].quantile(0.25)
    upper_threshold = df[column].quantile(0.75) + (1.5*iqr)
    lower_threshold = df[column].quantile(0.25) - (1.5*iqr)
    df[column] = df[column].clip(lower_threshold, upper_threshold)

# %%
outlier(df_copy, 'floor_area_sqm')
outlier(df_copy, 'resale_price_log')

# %%
for i in ['floor_area_sqm','lease_commence_date_year','resale_price_log']:
    plot(df_copy,i)

# %%
df_copy.head()
# Out:
#          town flat_type       street_name storey_range  floor_area_sqm  \
# 0  ANG MO KIO    1 ROOM  ANG MO KIO AVE 1     10 TO 12            31.0
# 1  ANG MO KIO    1 ROOM  ANG MO KIO AVE 1     04 TO 06            31.0
# 2  ANG MO KIO    1 ROOM  ANG MO KIO AVE 1     10 TO 12            31.0
# 3  ANG MO KIO    1 ROOM  ANG MO KIO AVE 1     07 TO 09            31.0
# 4  ANG MO KIO    3 ROOM  ANG MO KIO AVE 1     04 TO 06            73.0
#
#        flat_model  resale_price  month_year  month_month  \
# 0        IMPROVED        9000.0        1990            1
# 1        IMPROVED        6000.0        1990            1
# 2        IMPROVED        8000.0        1990            1
# 3        IMPROVED        6000.0        1990            1
# 4  NEW GENERATION       47200.0        1990            1
#
#    lease_commence_date_year  resale_price_log
# 0                      1977         10.987887
# 1                      1977         10.987887
# 2                      1977         10.987887
# ...

# %%
#dropping unwanted columns 
df_copy.drop(columns = ['resale_price'], axis =1, inplace = True)
df_copy.head(4)
# Out:
#          town flat_type       street_name storey_range  floor_area_sqm  \
# 0  ANG MO KIO    1 ROOM  ANG MO KIO AVE 1     10 TO 12            31.0
# 1  ANG MO KIO    1 ROOM  ANG MO KIO AVE 1     04 TO 06            31.0
# 2  ANG MO KIO    1 ROOM  ANG MO KIO AVE 1     10 TO 12            31.0
# 3  ANG MO KIO    1 ROOM  ANG MO KIO AVE 1     07 TO 09            31.0
#
#   flat_model  month_year  month_month  lease_commence_date_year  \
# 0   IMPROVED        1990            1                      1977
# 1   IMPROVED        1990            1                      1977
# 2   IMPROVED        1990            1                      1977
# 3   IMPROVED        1990            1                      1977
#
#    resale_price_log
# 0         10.987887
# 1         10.987887
# 2         10.987887
# 3         10.987887

# %%
df_copy['town'].value_counts()
# Out:
# town
# TAMPINES           77295
# YISHUN             67902
# BEDOK              64215
# JURONG WEST        63796
# WOODLANDS          62930
# ANG MO KIO         50216
# HOUGANG            48837
# BUKIT BATOK        42900
# CHOA CHU KANG      36547
# BUKIT MERAH        32998
# PASIR RIS          32039
# TOA PAYOH          30420
# SENGKANG           29841
# QUEENSTOWN         27801
# GEYLANG            27129
# CLEMENTI           27095
# BUKIT PANJANG      26291
# KALLANG/WHAMPOA    26032
# JURONG EAST        23952
# SERANGOON          21995
# BISHAN             20574
# PUNGGOL            19088
# SEMBAWANG          12845
# MARINE PARADE       7815
# CENTRAL AREA        6735
# BUKIT TIMAH         2428
# LIM CHU KANG          64
# Name: count, dtype: int64

# %%
# Calculate counts of each category
counts = df_copy['town'].value_counts()

threshold = 1000

# Identify categories with counts below threshold
rare_categories = counts[counts < threshold].index

# Replace rare categories with 'Other'
df_copy.loc[df_copy['town'].isin(rare_categories), 'town'] = 'Other'

# %%
df_copy['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              337075
# 3 ROOM              285907
# 5 ROOM              186667
# EXECUTIVE            66824
# 2 ROOM               11479
# 1 ROOM                1290
# MULTI GENERATION       279
# MULTI-GENERATION       259
# Name: count, dtype: int64

# %%
# Calculate counts of each category
counts = df_copy['flat_type'].value_counts()

threshold = 1000

# Identify categories with counts below threshold
rare_categories = counts[counts < threshold].index

# Replace rare categories with 'Other'
df_copy.loc[df_copy['flat_type'].isin(rare_categories), 'flat_type'] = 'Other'

# %%
df_copy['street_name'].value_counts()
# Out:
# street_name
# YISHUN RING RD            16977
# BEDOK RESERVOIR RD        14216
# ANG MO KIO AVE 10         13334
# ANG MO KIO AVE 3          11707
# HOUGANG AVE 8              9022
# TAMPINES ST 21             8064
# BEDOK NTH ST 3             7304
# BEDOK NTH RD               7176
# ANG MO KIO AVE 4           6975
# MARSILING DR               6455
# JURONG WEST ST 42          6365
# ANG MO KIO AVE 5           6189
# LOR 1 TOA PAYOH            5332
# SIMEI ST 1                 5330
# BT BATOK WEST AVE 6        5298
# JURONG EAST ST 21          5118
# CIRCUIT RD                 5107
# CLEMENTI AVE 4             4927
# TAMPINES ST 22             4903
# ANG MO KIO AVE 1           4883
# YISHUN ST 11               4752
# YISHUN ST 21               4748
# JURONG WEST ST 81          4626
# WOODLANDS ST 13            4585
# YISHUN ST 61               4582
# BISHAN ST 13               4576
# UBI AVE 1                  4529
# JURONG WEST ST 52          4505
# YISHUN ST 81               4455
# ...

# %%
# Calculate counts of each category
counts = df_copy['street_name'].value_counts()

threshold = 1000

# Identify categories with counts below threshold
rare_categories = counts[counts < threshold].index

# Replace rare categories with 'Other'
df_copy.loc[df_copy['street_name'].isin(rare_categories), 'street_name'] = 'Other'

# %%
df_copy['storey_range'].value_counts()
# Out:
# storey_range
# 04 TO 06    223641
# 07 TO 09    201915
# 01 TO 03    179318
# 10 TO 12    171752
# 13 TO 15     58825
# 16 TO 18     22851
# 19 TO 21     10912
# 22 TO 24      7065
# 25 TO 27      3251
# 01 TO 05      2700
# 06 TO 10      2474
# 28 TO 30      1526
# 11 TO 15      1259
# 31 TO 33       576
# 34 TO 36       522
# 37 TO 39       454
# 16 TO 20       265
# 40 TO 42       219
# 21 TO 25        92
# 43 TO 45        56
# 46 TO 48        44
# 26 TO 30        39
# 49 TO 51        15
# 36 TO 40         7
# 31 TO 35         2
# Name: count, dtype: int64

# %%
# Calculate counts of each category
counts = df_copy['storey_range'].value_counts()

threshold = 1000

# Identify categories with counts below threshold
rare_categories = counts[counts < threshold].index

# Replace rare categories with 'Other'
df_copy.loc[df_copy['storey_range'].isin(rare_categories), 'storey_range'] = 'Other'

# %%
df_copy['flat_model'].value_counts()
# Out:
# flat_model
# Model A                   183542
# Improved                  158683
# New Generation            103735
# NEW GENERATION             78898
# IMPROVED                   73589
# MODEL A                    70381
# Premium Apartment          43230
# Simplified                 32405
# Apartment                  24162
# Standard                   23979
# SIMPLIFIED                 23258
# STANDARD                   17375
# Maisonette                 16412
# MAISONETTE                 12215
# APARTMENT                   9901
# Model A2                    9562
# DBSS                        3098
# Adjoined flat               1199
# Model A-Maisonette          1025
# MODEL A-MAISONETTE           982
# Terrace                      423
# Type S1                      299
# MULTI GENERATION             279
# Multi Generation             259
# TERRACE                      247
# Type S2                      162
# 2-room                       112
# Premium Apartment Loft       103
# ...

# %%
# Calculate counts of each category
counts = df_copy['flat_model'].value_counts()

threshold = 1000

# Identify categories with counts below threshold
rare_categories = counts[counts < threshold].index

# Replace rare categories with 'Other'
df_copy.loc[df_copy['flat_model'].isin(rare_categories), 'flat_model'] = 'Other'

# %%
df2 = df_copy.copy()

# %% [markdown]
# # Encoding and scaling data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.feature_selection import RFE
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import RandomizedSearchCV
import joblib

# %%
# Function to evaluate model
def evaluate_model(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("Mean Squared Error:", mse)
    print("Mean Absolute Error:", mae)
    print("R2 Score:", r2)
    
    # Flatten y_test and y_pred if they are 2D arrays
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()
    
    plt.figure(figsize=(6, 6))
    sns.scatterplot(x=y_test_flat, y=y_pred_flat, alpha=0.3)
    plt.plot([y_test_flat.min(), y_test_flat.max()], [y_test_flat.min(), y_test_flat.max()], '--', color='red')
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.title('Actual vs Predicted')
    plt.show()

# %%
# Define features and target variable for the subset
X_subset = df2.drop(columns=['resale_price_log'])
y_subset = df2['resale_price_log']

# %%
# Splitting the subset data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_subset, y_subset, test_size=0.2, random_state=42)

# %%
# Label Encoding for categorical features
categorical_encoded = ['town','flat_type','street_name','storey_range','flat_model','month_month']
label_encoders = {}
for col in categorical_encoded:
    label_encoders[col] = LabelEncoder()
    X_train[col] = label_encoders[col].fit_transform(X_train[col])
    X_test[col] = label_encoders[col].transform(X_test[col])

# %%
# Standard Scaling for numerical features
numerical_scaled = ['floor_area_sqm', 'month_year', 'lease_commence_date_year'] 
scaler_features = StandardScaler()
X_train[numerical_scaled] = scaler_features.fit_transform(X_train[numerical_scaled])
X_test[numerical_scaled] = scaler_features.transform(X_test[numerical_scaled])

# %%
# Reshape y_train and y_test to be 2D arrays
y_train_reshaped = np.array(y_train).reshape(-1, 1)
y_test_reshaped = np.array(y_test).reshape(-1, 1)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train_reshaped)
y_test_scaled = scaler_y.transform(y_test_reshaped)

# %%
selected_features = ['town','flat_type','street_name','storey_range','flat_model',
                     'month_month','floor_area_sqm', 'month_year', 'lease_commence_date_year' ]

# %%
# Selecting features for training from balanced data
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

# %%
# Decision Tree Regressor
print("\nDecision Tree Regressor:")
dt_regressor = DecisionTreeRegressor(max_depth=4, random_state=42)
evaluate_model(dt_regressor, X_train_selected, X_test_selected, y_train_scaled, y_test_scaled)
# Out:
# Decision Tree Regressor:
# Mean Squared Error: 0.1469044912229602
# Mean Absolute Error: 0.2936873067333776
# R2 Score: 0.8531801860799972

# %%
# Random Forest Regressor
print("\nRandom Forest Regressor:")
rf_regressor = RandomForestRegressor(n_estimators=50, random_state=42)
evaluate_model(rf_regressor, X_train_selected, X_test_selected, y_train_scaled, y_test_scaled)
# Out:
# Random Forest Regressor:
# C:\Users\igomp\AppData\Local\Temp\ipykernel_11440\357422431.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# Mean Squared Error: 0.016499612958391106
# Mean Absolute Error: 0.0884214316954278
# R2 Score: 0.9835098975930803

# %%
# Gradient Boosting Regressor
print("\nGradient Boosting Regressor:")
gb_regressor = GradientBoostingRegressor(random_state=42)
evaluate_model(gb_regressor, X_train_selected, X_test_selected, y_train_scaled, y_test_scaled)
# Out:
# Gradient Boosting Regressor:
# C:\Users\igomp\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Squared Error: 0.05140331100553252
# Mean Absolute Error: 0.1722772815085138
# R2 Score: 0.9486263184067666

# %%
# XGBoost Regressor
print("\nXGBoost Regressor:")
xgb_regressor = XGBRegressor(n_estimators=100, max_depth=5, learning_rate=0.1, random_state=42)
evaluate_model(xgb_regressor, X_train_selected, X_test_selected, y_train_scaled, y_test_scaled)
# Out:
# XGBoost Regressor:
# Mean Squared Error: 0.03090340235568055
# Mean Absolute Error: 0.13184883834392355
# R2 Score: 0.9691144106923884

# %%
# K-Nearest Neighbors Regressor
print("\nK-Nearest Neighbors Regressor:")
knn_regressor = KNeighborsRegressor(n_neighbors=5)
evaluate_model(knn_regressor, X_train_selected, X_test_selected, y_train_scaled, y_test_scaled)
# Out:
# K-Nearest Neighbors Regressor:
# Mean Squared Error: 0.14610822969928122
# Mean Absolute Error: 0.2681031873196038
# R2 Score: 0.8539759886301097

# %%
# LightGBM Regressor
print("\nLightGBM Regressor:")
lgb_regressor = LGBMRegressor(random_state=42)
evaluate_model(lgb_regressor, X_train_selected, X_test_selected, y_train_scaled, y_test_scaled)
# Out:
# LightGBM Regressor:
# C:\Users\igomp\anaconda3\Lib\site-packages\lightgbm\basic.py:355: UserWarning: Converting column-vector to 1d array
#   _log_warning("Converting column-vector to 1d array")
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039278 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 545
# [LightGBM] [Info] Number of data points in the train set: 711824, number of used features: 9
# [LightGBM] [Info] Start training from score -0.000000
# Mean Squared Error: 0.025816895277890505
# Mean Absolute Error: 0.1202173953247366
# R2 Score: 0.9741979858536847

# %%
# CatBoost Regressor
print("\nCatBoost Regressor:")
cat_regressor = CatBoostRegressor(random_state=42, verbose=0)
evaluate_model(cat_regressor, X_train_selected, X_test_selected, y_train_scaled, y_test_scaled)
# Out:
# CatBoost Regressor:
# Mean Squared Error: 0.01668401123346009
# Mean Absolute Error: 0.0935913125743543
# R2 Score: 0.983325605607128

# %% [markdown]
# # Best model for Regression:¶
#
# We can see that CatBoost Regressor model has the best performance of the above models

# %%
import joblib
joblib.dump(df_copy, 'D:/Vscode/real_estate/df.joblib')
# Dump columns for price
joblib.dump(categorical_encoded, 'D:/Vscode/real_estate/categorical_encoded.joblib')
joblib.dump(numerical_scaled, 'D:/Vscode/real_estate/numerical_scaled.joblib')

# Dump encoders for price
joblib.dump(label_encoders, 'D:/Vscode/real_estate/label_encoders.joblib')

# Dump scalers price
joblib.dump(scaler_features, 'D:/Vscode/real_estate/scaler_features.joblib')
joblib.dump(scaler_y, 'D:/Vscode/real_estate/scaler_target.joblib')

#dump model
joblib.dump(cat_regressor, 'D:/Vscode/real_estate/cat_regressor_model.joblib')
# Out:
# ['D:/Vscode/real_estate/cat_regressor_model.joblib']
